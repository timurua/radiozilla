# %%
# !pip3 install google-cloud-firestore
# Out:
# Collecting google-cloud-firestore
#   Downloading google_cloud_firestore-2.19.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Collecting google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore)
#   Downloading google_api_core-2.22.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1 (from google-cloud-firestore)
#   Downloading google_auth-2.35.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting google-cloud-core<3.0.0dev,>=1.4.1 (from google-cloud-firestore)
#   Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl.metadata (2.7 kB)
# Collecting proto-plus<2.0.0dev,>=1.22.0 (from google-cloud-firestore)
#   Downloading proto_plus-1.25.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.2 (from google-cloud-firestore)
#   Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting googleapis-common-protos<2.0.dev0,>=1.56.2 (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore)
#   Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in ./lib/python3.12/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore) (2.32.3)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in ./lib/python3.12/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore) (1.67.0)
# Collecting grpcio-status<2.0.dev0,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore)
#   Downloading grpcio_status-1.67.1-py3-none-any.whl.metadata (1.1 kB)
# Collecting cachetools<6.0,>=2.0.0 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-firestore)
#   Downloading cachetools-5.5.0-py3-none-any.whl.metadata (5.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-firestore)
#   Downloading pyasn1_modules-0.4.1-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-firestore)
#   Downloading rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting grpcio<2.0dev,>=1.33.2 (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore)
#   Downloading grpcio-1.67.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.9 kB)
# Collecting pyasn1<0.7.0,>=0.4.6 (from pyasn1-modules>=0.2.1->google-auth!=2.24.0,!=2.25.0,<3.0.0dev,>=2.14.1->google-cloud-firestore)
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.12/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.0->google-cloud-firestore) (2024.8.30)
# Downloading google_cloud_firestore-2.19.0-py2.py3-none-any.whl (336 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 336.8/336.8 kB 5.2 MB/s eta 0:00:007.8 MB/s eta 0:00:01
# Downloading google_api_core-2.22.0-py3-none-any.whl (156 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 156.5/156.5 kB 3.9 MB/s eta 0:00:000:00:01
# Downloading google_auth-2.35.0-py2.py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.0/209.0 kB 6.3 MB/s eta 0:00:00
# Downloading google_cloud_core-2.4.1-py2.py3-none-any.whl (29 kB)
# Downloading proto_plus-1.25.0-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 1.7 MB/s eta 0:00:00
# Downloading protobuf-5.28.3-cp38-abi3-manylinux2014_x86_64.whl (316 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.6/316.6 kB 7.0 MB/s eta 0:00:0013.0 MB/s eta 0:00:01
# Downloading cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Downloading googleapis_common_protos-1.65.0-py2.py3-none-any.whl (220 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.9/220.9 kB 6.9 MB/s eta 0:00:00
# Downloading grpcio_status-1.67.1-py3-none-any.whl (14 kB)
# Downloading grpcio-1.67.1-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 8.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Downloading pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 181.5/181.5 kB 3.5 MB/s eta 0:00:004 MB/s eta 0:00:01
# Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 2.9 MB/s eta 0:00:00
# Installing collected packages: pyasn1, protobuf, grpcio, cachetools, rsa, pyasn1-modules, proto-plus, googleapis-common-protos, grpcio-status, google-auth, google-api-core, google-cloud-core, google-cloud-firestore
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.67.0
#     Uninstalling grpcio-1.67.0:
#       Successfully uninstalled grpcio-1.67.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# descript-audiotools 0.7.2 requires protobuf<3.20,>=3.9.2, but you have protobuf 5.28.3 which is incompatible.
# Successfully installed cachetools-5.5.0 google-api-core-2.22.0 google-auth-2.35.0 google-cloud-core-2.4.1 google-cloud-firestore-2.19.0 googleapis-common-protos-1.65.0 grpcio-1.67.1 grpcio-status-1.67.1 proto-plus-1.25.0 protobuf-5.28.3 pyasn1-0.6.1 pyasn1-modules-0.4.1 rsa-4.9
# Collecting git+https://****@github.com/timurua/radiozilla.git#subdirectory=backend/pyradiozilla
#   Cloning https://****@github.com/timurua/radiozilla.git to /tmp/pip-req-build-56kij220
#   Running command git clone --filter=blob:none --quiet 'https://****@github.com/timurua/radiozilla.git' /tmp/pip-req-build-56kij220
#   Resolved https://****@github.com/timurua/radiozilla.git to commit 8b19b15e1c91c19993494e4e429456ea126cf38a
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting PyGithub==2.4.0 (from pyradiozilla==0.1.5)
#   Downloading PyGithub-2.4.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting pynacl>=1.4.0 (from PyGithub==2.4.0->pyradiozilla==0.1.5)
#   Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl.metadata (8.6 kB)
# Requirement already satisfied: requests>=2.14.0 in ./lib/python3.12/site-packages (from PyGithub==2.4.0->pyradiozilla==0.1.5) (2.32.3)
# Collecting pyjwt>=2.4.0 (from pyjwt[crypto]>=2.4.0->PyGithub==2.4.0->pyradiozilla==0.1.5)
#   Downloading PyJWT-2.9.0-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: typing-extensions>=4.0.0 in ./lib/python3.12/site-packages (from PyGithub==2.4.0->pyradiozilla==0.1.5) (4.12.2)
# Requirement already satisfied: urllib3>=1.26.0 in ./lib/python3.12/site-packages (from PyGithub==2.4.0->pyradiozilla==0.1.5) (2.2.3)
# Collecting Deprecated (from PyGithub==2.4.0->pyradiozilla==0.1.5)
#   Downloading Deprecated-1.2.14-py2.py3-none-any.whl.metadata (5.4 kB)
# Collecting cryptography>=3.4.0 (from pyjwt[crypto]>=2.4.0->PyGithub==2.4.0->pyradiozilla==0.1.5)
#   Downloading cryptography-43.0.3-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: cffi>=1.4.1 in ./lib/python3.12/site-packages (from pynacl>=1.4.0->PyGithub==2.4.0->pyradiozilla==0.1.5) (1.17.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./lib/python3.12/site-packages (from requests>=2.14.0->PyGithub==2.4.0->pyradiozilla==0.1.5) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in ./lib/python3.12/site-packages (from requests>=2.14.0->PyGithub==2.4.0->pyradiozilla==0.1.5) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in ./lib/python3.12/site-packages (from requests>=2.14.0->PyGithub==2.4.0->pyradiozilla==0.1.5) (2024.8.30)
# Collecting wrapt<2,>=1.10 (from Deprecated->PyGithub==2.4.0->pyradiozilla==0.1.5)
#   Downloading wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: pycparser in ./lib/python3.12/site-packages (from cffi>=1.4.1->pynacl>=1.4.0->PyGithub==2.4.0->pyradiozilla==0.1.5) (2.22)
# Downloading PyGithub-2.4.0-py3-none-any.whl (362 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.6/362.6 kB 1.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading PyJWT-2.9.0-py3-none-any.whl (22 kB)
# Downloading PyNaCl-1.5.0-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (856 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 856.7/856.7 kB 3.2 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Downloading Deprecated-1.2.14-py2.py3-none-any.whl (9.6 kB)
# Downloading cryptography-43.0.3-cp39-abi3-manylinux_2_28_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 8.1 MB/s eta 0:00:00m eta 0:00:010:00:01
# Downloading wrapt-1.16.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (87 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.3/87.3 kB 6.3 MB/s eta 0:00:00
# Building wheels for collected packages: pyradiozilla
#   Building wheel for pyradiozilla (pyproject.toml) ... done
#   Created wheel for pyradiozilla: filename=pyradiozilla-0.1.5-py3-none-any.whl size=3308 sha256=0c7c4ab63d159c60a0316340c97e038579c7c8efcb24ecf1a0ae3187964c01a9
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s6m7tu7w/wheels/96/39/f8/8415906db689dc2830cb8fa97685610a525900927922e212ee
# Successfully built pyradiozilla
# Installing collected packages: wrapt, pyjwt, pynacl, Deprecated, cryptography, PyGithub, pyradiozilla
# Successfully installed Deprecated-1.2.14 PyGithub-2.4.0 cryptography-43.0.3 pyjwt-2.9.0 pynacl-1.5.0 pyradiozilla-0.1.5 wrapt-1.16.0

# %%
from google.cloud import firestore

service_account_key_path = "/home/timur/radiozilla/backend/notebooks/firestore_service_account.json"

# Initialize the Firestore client with the service account JSON file
db = firestore.Client.from_service_account_json(service_account_key_path)

# %%
docs = db.collection('audios').stream()

for doc in docs:
    print(f'{doc.id} => {doc.to_dict()}')
# Out:
# 1 => {'imageUrl': 'https://www.iana.org/_img/2022/iana-logo-header.svg', 'audioUrl': 'https://cdn.pixabay.com/audio/2022/08/23/audio_d16737dc28.mp3', 'topics': ['Technology'], 'createdAt': DatetimeWithNanoseconds(2024, 10, 30, 0, 0, tzinfo=datetime.timezone.utc), 'channel': 'channels/linux_kernel', 'author': 'authors/github_sun', 'name': 'Digest 1'}
# 2 => {'imageUrl': 'https://cdn.pixabay.com/photo/2021/11/04/05/33/dome-6767422_960_720.jpg', 'audioUrl': 'https://cdn.pixabay.com/audio/2022/08/04/audio_2dde668d05.mp3', 'topics': ['Technology'], 'createdAt': DatetimeWithNanoseconds(2024, 10, 30, 0, 0, tzinfo=datetime.timezone.utc), 'channel': 'channels/linux_kernel', 'author': 'authors/github_sun', 'name': 'Digest 2'}
# 3 => {'imageUrl': 'https://cdn.pixabay.com/photo/2022/08/29/08/47/sky-7418364__340.jpg', 'audioUrl': 'https://cdn.pixabay.com/audio/2022/08/04/audio_2dde668d05.mp3', 'topics': ['Technology'], 'createdAt': DatetimeWithNanoseconds(2024, 10, 30, 0, 0, tzinfo=datetime.timezone.utc), 'channel': 'channels/linux_kernel', 'author': 'authors/github_sun', 'name': 'Digest 2'}
# some_audio => {'audioUrl': 'https://cdn.pixabay.com/audio/2022/08/23/audio_d16737dc28.mp3', 'imageUrl': 'https://www.iana.org/_img/2022/iana-logo-header.svg', 'topics': ['Technology'], 'createdAt': DatetimeWithNanoseconds(2024, 11, 1, 7, 0, 0, 432000, tzinfo=datetime.timezone.utc), 'author': 'authors/github_sun', 'channel': <google.cloud.firestore_v1.document.DocumentReference object at 0x7b0d43fda1e0>, 'name': 'Digest'}

# %%
from datetime import datetime

channels_to_add = {
    "linux_kernel": {
        "name": "Linux Kernel updates",
        "description": "Linux Kernel updates",
        "imageUrl": "https://icon.icepanel.io/Technology/png-shadow-512/Linux.png"
    }
}

for key, value in channels_to_add.items():
    print(f"Updating channels key: {key}, value: {value}")
    db.collection("channels").document(key).set(value)


authors_to_add = {
    "linux_kernel": {
        "name": "Linux Kernel Summarizer",
        "description": "Linux Kernel Summarizer",
        "imageUrl": "https://icon.icepanel.io/Technology/png-shadow-512/Linux.png"
    }
}

for key, value in channels_to_add.items():
    print(f"Updating authors key: {key}, value: {value}")
    db.collection("author").document(key).set(value)

audios_to_add = {
    "1": {
        "audioUrl": "https://cdn.pixabay.com/audio/2022/08/23/audio_d16737dc28.mp3",
        "author": "authors/github_sun",
        "channel": "channels/linux_kernel",
        "createdAt":  datetime(2024, 10, 30),
        "imageUrl": "https://www.iana.org/_img/2022/iana-logo-header.svg",
        "name": "Digest 1",
        "topics": ["Technology"],
    },
    "2": {
        "audioUrl": "https://cdn.pixabay.com/audio/2022/08/04/audio_2dde668d05.mp3",
        "author": "authors/github_sun",
        "channel": "channels/linux_kernel",
        "createdAt": datetime(2024, 10, 30),
        "imageUrl": "https://cdn.pixabay.com/photo/2021/11/04/05/33/dome-6767422_960_720.jpg",
        "name": "Digest 2",
        "topics": ["Technology"]
    },
    "3": {
        "audioUrl": "https://cdn.pixabay.com/audio/2022/08/04/audio_2dde668d05.mp3",
        "author": "authors/github_sun",
        "channel": "channels/linux_kernel",
        "createdAt": datetime(2024, 10, 30),
        "imageUrl": "https://cdn.pixabay.com/photo/2022/08/29/08/47/sky-7418364__340.jpg",
        "name": "Digest 2",
        "topics": ["Technology"],
    }
}


for key, value in audios_to_add.items():
    print(f"Updating audios key: {key}, value: {value}")
    db.collection("audios").document(key).set(value)
# Out:
# Updating channels key: linux_kernel, value: {'name': 'Linux Kernel updates', 'description': 'Linux Kernel updates', 'imageUrl': 'https://icon.icepanel.io/Technology/png-shadow-512/Linux.png'}
# Updating authors key: linux_kernel, value: {'name': 'Linux Kernel updates', 'description': 'Linux Kernel updates', 'imageUrl': 'https://icon.icepanel.io/Technology/png-shadow-512/Linux.png'}
# Updating audios key: 1, value: {'audioUrl': 'https://cdn.pixabay.com/audio/2022/08/23/audio_d16737dc28.mp3', 'author': 'authors/github_sun', 'channel': 'channels/linux_kernel', 'createdAt': datetime.datetime(2024, 10, 30, 0, 0), 'imageUrl': 'https://www.iana.org/_img/2022/iana-logo-header.svg', 'name': 'Digest 1', 'topics': ['Technology']}
# Updating audios key: 2, value: {'audioUrl': 'https://cdn.pixabay.com/audio/2022/08/04/audio_2dde668d05.mp3', 'author': 'authors/github_sun', 'channel': 'channels/linux_kernel', 'createdAt': datetime.datetime(2024, 10, 30, 0, 0), 'imageUrl': 'https://cdn.pixabay.com/photo/2021/11/04/05/33/dome-6767422_960_720.jpg', 'name': 'Digest 2', 'topics': ['Technology']}
# Updating audios key: 3, value: {'audioUrl': 'https://cdn.pixabay.com/audio/2022/08/04/audio_2dde668d05.mp3', 'author': 'authors/github_sun', 'channel': 'channels/linux_kernel', 'createdAt': datetime.datetime(2024, 10, 30, 0, 0), 'imageUrl': 'https://cdn.pixabay.com/photo/2022/08/29/08/47/sky-7418364__340.jpg', 'name': 'Digest 2', 'topics': ['Technology']}
