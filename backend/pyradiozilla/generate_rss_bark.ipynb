# %% [markdown]
# # Retrieve RSS

# %%
# !pip install feedparser requests importlib bs4 ffmpeg-python nltk soundfile numpy scipy firebase-admin google-cloud-firestore joblib
# !pip install git+https://github.com/suno-ai/bark.git

# %%
from pyradiozilla import firebase

rz_firebase = firebase.Firebase()

# %%
from pyradiozilla import firebase

rz_author = firebase.RzAuthor(
    id= firebase.generate_url_safe_id('rss/weekly'),
    name='rss/weekly',
    description='Weekly rss summary scraper',        
    image=firebase.Blob(file_path="images/file-person.svg")
)
rz_author.upload_and_save(rz_firebase)
rz_channel = firebase.RzChannel(
    id= firebase.generate_url_safe_id('rss/python'),
    name='rss/python',    
    description='Latest updates about python programming language.',
    source_urls=['http://feeds.feedburner.com/PythonInsider'],
    image=firebase.Blob(file_path="images/rss.svg")
)
rz_channel.upload_and_save(rz_firebase)

# %%
from pyradiozilla import rss
from pyradiozilla import prompts
from pyradiozilla import ollama
from pyradiozilla import tts
from pyradiozilla import storage
import IPython
from pyradiozilla import firebase
from joblib import Parallel, delayed
import time
from typing import NamedTuple
from datetime import datetime

class Summary(NamedTuple):
    start_date: datetime
    prompt: str
    summary: str    
    directory: str

root_directory = storage.Directory("/media/timur/TESLA SSD")
print(f"Started scraping summary")    
entries = rss.RssScraper('http://feeds.feedburner.com/PythonInsider').parse()
summaryConfug = prompts.SummaryConfig(
    "English",
    prompts.SummaryLength.medium,
    prompts.SummaryTone.neutral,
    [prompts.SummaryFocus.key_points],
)

rss_prompts = prompts.RssWeeklySummaryPropmpt(entries, summaryConfug).get_prompts() 

print(f"Finished scraping summary")    
ollama_model = "gemma2:27b"

def create_summary(prompt: prompts.RssPrompt) -> Summary:
    print(f"Started rocessing weekly summary {prompt.start_date}")
    summary_directory = root_directory.get_timed_directory("run")
    summary_directory.get_file("prompt.txt").write_text(prompt.prompt)
    ollama_client = ollama.OllamaClient(ollama_model)       
    summary = ollama_client.generate(prompt.prompt)
    summary_directory.get_file("summary.txt").write_text(summary)
    print(f"Finished processing weekly summary {prompt.start_date}")    
    return Summary(
        start_date=prompt.start_date,
        prompt=prompt.prompt,
        summary=summary,
        directory=summary_directory.get_path()
    )
    
ollama.OllamaClient(ollama_model).unload_all_models()
    
print(f"Started summarizing")
        
rss_summaries = Parallel(n_jobs=4, backend='threading')(
    delayed(create_summary)(rss_prompt) for rss_prompt in rss_prompts
)

print(f"Started processing audio")

def create_audio(summary: Summary):
    print(f"Started processing audio {summary.start_date}")
    summary_directory = storage.Directory(summary.directory)
    audio = tts.BarkTTS.generate(summary.summary, summary_directory)
    rz_audio = firebase.RzAudio(
        id= firebase.generate_url_safe_uuid(),
        name='rss/python/weekly',
        description='Weekly rss summary about python programming language.',
        author_id=rz_author.id,
        channel_id=rz_channel.id,
        image=firebase.Blob(file_path="images/rss.svg"),
        audio=firebase.Blob(file_path=audio.m4a_file_path),
        topics=['Python', 'Programming']
    )
    summary_directory.get_file("rz_audio.txt").write_json(rz_audio)
    rz_audio.upload_and_save(rz_firebase)
    print(f"Finished processing audio {summary.start_date}")
    return summary    

IPython.display.display(rss_summaries)
    
rss_audios = Parallel(n_jobs=4, backend='threading')(
    delayed(create_audio)(
        Summary(
            start_date=rss_summary.start_date, 
            prompt=rss_summary.prompt, 
            summary=rss_summary.summary, 
            directory=rss_summary.directory
        )) for rss_summary in rss_summaries
)

IPython.display.display(rss_audios)
# Out:
# Started scraping summary
# Finished scraping summary
# Started summarizing
# Started rocessing weekly summary 2024-10-14 00:00:00
# Started rocessing weekly summary 2024-10-07 00:00:00
# Started rocessing weekly summary 2024-09-30 00:00:00
# Started rocessing weekly summary 2024-09-02 00:00:00
# Finished processing weekly summary 2024-10-14 00:00:00
# Started rocessing weekly summary 2024-08-05 00:00:00
# Finished processing weekly summary 2024-09-02 00:00:00
# Started rocessing weekly summary 2024-07-29 00:00:00
# Finished processing weekly summary 2024-09-30 00:00:00
# Started rocessing weekly summary 2024-07-15 00:00:00
# Finished processing weekly summary 2024-10-07 00:00:00
# Started rocessing weekly summary 2024-06-24 00:00:00
# Finished processing weekly summary 2024-08-05 00:00:00
# Started rocessing weekly summary 2024-06-03 00:00:00
# Finished processing weekly summary 2024-07-15 00:00:00
# Started rocessing weekly summary 2024-05-06 00:00:00
# Finished processing weekly summary 2024-06-24 00:00:00
# Started rocessing weekly summary 2024-04-08 00:00:00
# Finished processing weekly summary 2024-07-29 00:00:00
# Started rocessing weekly summary 2024-03-18 00:00:00
# Finished processing weekly summary 2024-06-03 00:00:00
# Started rocessing weekly summary 2024-03-11 00:00:00
# Finished processing weekly summary 2024-03-18 00:00:00
# Started rocessing weekly summary 2024-02-12 00:00:00
# Finished processing weekly summary 2024-04-08 00:00:00
# Started rocessing weekly summary 2024-02-05 00:00:00
# Finished processing weekly summary 2024-05-06 00:00:00
# Started rocessing weekly summary 2024-01-15 00:00:00
# Finished processing weekly summary 2024-02-05 00:00:00
# Started rocessing weekly summary 2023-12-04 00:00:00
# Finished processing weekly summary 2024-02-12 00:00:00
# Started rocessing weekly summary 2023-11-20 00:00:00
# Finished processing weekly summary 2024-01-15 00:00:00
# Started rocessing weekly summary 2023-10-09 00:00:00
# Finished processing weekly summary 2024-03-11 00:00:00
# Started rocessing weekly summary 2023-10-02 00:00:00
# Finished processing weekly summary 2023-10-09 00:00:00
# Finished processing weekly summary 2023-12-04 00:00:00
# Finished processing weekly summary 2023-11-20 00:00:00
# Finished processing weekly summary 2023-10-02 00:00:00
# Started processing audio
# [Summary(start_date=datetime.datetime(2024, 10, 14, 0, 0), prompt="Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-10-14 to 2024-10-20:\n\nPython 3.14.0 alpha 1 is now available: It's now time for a new alpha of a new version of Python!\nhttps://www.python.org/downloads/release/python-3140a1/\nThis is an early developer preview of Python\n3.14\nMajor\nnew features of the 3.14 series, compared to 3.13\nPython 3.14 is still in development. This release, 3.14.0a1 is the\nfirst of seven planned alpha releases.\nAlpha releases are intended to make it easier to test the current\nstate of new features and bug fixes and to test the release process.\nDuring the alpha phase, features may be added up until the start of\nthe beta phase (2025-05-06) and, if necessary, may be modified or\ndeleted up until the release candidate phase (2025-07-22). Please keep\nin mind that this is a preview release and its use is\nnot recommended for production environments.\nMany new features for Python 3.14 are still being planned and\nwritten. Among the new major new features and changes so far:\n\nPEP 649: deferred\nevaluation of annotations\nImproved\nerror messages\n(Hey, fellow core developer, if a feature\nyou find important is missing from this list, let Hugo know.)\n\nThe next pre-release of Python 3.14 will be 3.14.0a2, currently\nscheduled for 2024-11-19.\nMore resources\n\nOnline\ndocumentation\nPEP 745, 3.14\nRelease Schedule\nReport bugs at https://github.com/python/cpython/issues\nHelp fund Python and its\ncommunity\n\nEnjoy the new release\nThanks to all of the many volunteers who help make Python Development\nand these releases possible! Please consider supporting our efforts by\nvolunteering yourself or through organization contributions to the\nPython Software Foundation.\nRegards from a grey yet colourful Helsinki,\nYour release team,\nHugo van Kemenade\nNed Deily\nSteve Dower\nŁukasz Langa", summary='Python 3.14.0 alpha 1 has been released, marking the beginning of development for this new Python version. This alpha release is intended for developers to test early features and bug fixes.\n\nKey changes in Python 3.14 include deferred evaluation of annotations (PEP 649) and improved error messages. More features are planned and will be added throughout the alpha, beta, and release candidate phases.\n\nThis alpha version is not recommended for production environments. The next pre-release, 3.14.0a2, is scheduled for November 19th, 2024.\n\n\nThe Python Software Foundation encourages community involvement through volunteering or donations to support the ongoing development of Python.', directory='/media/timur/TESLA SSD/2024-11-14T13.46.08.069258_run'),
#  Summary(start_date=datetime.datetime(2024, 10, 7, 0, 0), prompt='Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-10-07 to 2024-10-13:\n\nPython 3.13.0 (final) released: Python 3.13.0 is now availablehttps://www.python.org/downloads/release/python-3130/This is the stable release of Python 3.13.0Python 3.13.0 is the newest major release of the Python programming language, and it contains many new features and optimizations compared to Python 3.12. (Compared to the last release candidate, 3.13.0rc3, 3.13.0 contains two small bug fixes and some documentation and testing changes.)Major new features of the 3.13 series, compared to 3.12Some of the new major new features and changes in Python 3.13 are:New featuresA\xa0new and improved interactive interpreter, based on\xa0PyPy’s, featuring multi-line editing and color support, as well as colorized\xa0exception tracebacks.An\xa0experimental\xa0free-threaded build mode, which disables the Global Interpreter Lock, allowing threads to run more concurrently. The build mode is available as an experimental feature in the Windows and macOS installers as well.A\xa0preliminary,\xa0experimental\xa0JIT, providing the ground work for significant performance improvements.The\xa0locals()\xa0builtin function (and its C equivalent) now has\xa0well-defined semantics when mutating the returned mapping, which allows debuggers to operate more consistently.A modified version of\xa0mimalloc\xa0is now included, optional but enabled by default if supported by the platform, and required for the free-threaded build mode.Docstrings now have\xa0their leading indentation stripped, reducing memory use and the size of .pyc files. (Most tools handling docstrings already strip leading indentation.)The\xa0dbm module\xa0has a new\xa0dbm.sqlite3 backend\xa0that is used by default when creating new files.The minimum supported macOS version was changed from 10.9 to\xa010.13 (High Sierra). Older macOS versions will not be supported going forward.WASI is now a\xa0Tier 2 supported platform. Emscripten is no longer an\xa0officially supported platform\xa0(but\xa0Pyodide\xa0continues to support Emscripten).iOS is now a\xa0Tier 3 supported platform.Android is now a\xa0Tier 3 supported platform.TypingSupport for\xa0type defaults in type parameters.A\xa0new type narrowing annotation,\xa0typing.TypeIs.A new annotation for\xa0read-only items in TypeDicts.A new annotation for\xa0marking deprecations in the type system.Removals and new deprecationsPEP 594 (Removing dead batteries from the standard library)\xa0scheduled removals of many deprecated modules:\xa0aifc,\xa0audioop,\xa0chunk,\xa0cgi,\xa0cgitb,\xa0crypt,\xa0imghdr,\xa0mailcap,\xa0msilib,\xa0nis,\xa0nntplib,\xa0ossaudiodev,\xa0pipes,\xa0sndhdr,\xa0spwd,\xa0sunau,\xa0telnetlib,\xa0uu,\xa0xdrlib,\xa0lib2to3.Many other removals\xa0of deprecated classes, functions and methods in various standard library modules.C API\xa0removals\xa0and\xa0deprecations. (Some removals present in alpha 1 were reverted in alpha 2, as the removals were deemed too disruptive at this time.)New deprecations, most of which are scheduled for removal from Python 3.15 or 3.16.For more details on the changes to Python 3.13, see\xa0What’s new in Python 3.13.More resourcesOnline DocumentationPEP 719, 3.13 Release ScheduleReport bugs via\xa0GitHub Issues.Help fund Python directly\xa0(or\xa0via GitHub Sponsors), and support\xa0the Python community.We hope you enjoy the new releases!Thanks to all of the many volunteers who help make Python Development and these releases possible! Please consider supporting our efforts by volunteering yourself or through organization contributions to\xa0the Python Software Foundation.Choo-choo from the release train,Your release team,Thomas Wouters\xa0Ned Deily\xa0Steve Dower\xa0Łukasz Langa', summary='Python 3.13.0, a major new release of the programming language, has been released.\n\n**Key improvements inc ...
#  Summary(start_date=datetime.datetime(2024, 9, 30, 0, 0), prompt="Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-09-30 to 2024-10-06:\n\nPython 3.12.7 released: I'm pleased to announce the release of Python 3.12.7:https://www.python.org/downloads/release/python-3127/\xa0This is the seventh maintenance release of Python 3.12Python 3.12 is the\xa0newest\xa0major release of the Python programming language, and it contains many new features and optimizations. 3.12.7 is the latest maintenance release, containing more than 100 bugfixes, build improvements and documentation changes since 3.12.6.\xa0Major new features of the 3.12 series, compared to 3.11\xa0New featuresMore flexible f-string parsing, allowing many things previously disallowed (PEP 701).Support for the buffer protocol\xa0in Python code (PEP 688).A new debugging/profiling API\xa0(PEP 669).Support for isolated subinterpreters\xa0with separate Global Interpreter Locks (PEP 684).Even more improved error messages. More exceptions potentially caused by typos now make suggestions to the user.Support for the Linux\xa0perf\xa0profiler\xa0to report Python function names in traces.Many large and small performance improvements\xa0(like\xa0PEP 709\xa0and support for the BOLT binary optimizer), delivering an estimated 5% overall performance improvement.Type annotationsNew type annotation syntax\xa0for generic classes (PEP 695).New override decorator\xa0for methods (PEP 698).DeprecationsThe deprecated\xa0wstr\xa0and\xa0wstr_length\xa0members of the C implementation of unicode objects were removed, per\xa0PEP 623.In the\xa0unittest\xa0module, a number of long deprecated methods and classes were removed. (They had been deprecated since Python 3.1 or 3.2).The deprecated\xa0smtpd\xa0and\xa0distutils\xa0modules have been removed (see\xa0PEP 594\xa0and\xa0PEP 632. The\xa0setuptools\xa0package continues to provide the\xa0distutils\xa0module.A number of other old, broken and deprecated functions, classes and methods\xa0have been removed.Invalid backslash escape sequences in strings now warn with\xa0SyntaxWarning\xa0instead of\xa0DeprecationWarning, making them more visible. (They will become syntax errors in the future.)The internal representation of integers has changed in preparation for performance enhancements. (This should not affect most users as it is an internal detail, but it may cause problems for Cython-generated code.)For more details on the changes to Python 3.12, see\xa0What’s new in Python 3.12.\xa0More resourcesOnline Documentation.PEP 693, the Python 3.12 Release Schedule.Report bugs via\xa0GitHub Issues.Help fund Python directly\xa0or\xa0via GitHub Sponsors, and support\xa0the Python community.\xa0Enjoy the new releasesThanks to all of the many volunteers who help make Python Development and these releases possible! Please consider supporting our efforts by volunteering yourself or through organization contributions to the Python Software Foundation.Your release team,Thomas WoutersŁukasz LangaNed DeilySteve Dower \nPython 3.13.0 release candidate 3 released: I'm pleased to announce the release of Python 3.13\xa0release candidate 3\xa0(instead of the expected final release).https://www.python.org/downloads/release/python-3130rc3/\xa0This is the final release candidate of Python 3.13.0This release, 3.13.0rc3, is the final release preview (no really) of 3.13. This release is expected to become the final 3.13.0 release, barring any critical bugs being discovered. The official release of 3.13.0 is now scheduled for Monday, 2024-10-07.This extra, unplanned release candidate exists because of a couple of last minute issues, primarily a significant performance regression in specific workloads due to the incremental cyclic garbage collector (introduced in the alpha releases). We decided to roll back the garbage collector change in 3.13 (and continuing work in 3.14 to improve it), apply a number of other impo ...
#  Summary(start_date=datetime.datetime(2024, 9, 2, 0, 0), prompt='Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-09-02 to 2024-09-08:\n\nPython 3.13.0RC2, 3.12.6, 3.11.10, 3.10.15, 3.9.20, and 3.8.20 are now available!: Hi there!\nA big joint release today. Mostly security fixes but we also have the final release candidate of 3.13 so let’s start with that!\nPython 3.13.0RC2\nFinal opportunity to test and find any show-stopper bugs before we bless and release 3.13.0 final on October 1st.\nGet it here: Python Release Python 3.13.0rc2 | Python.org\nCall to action\nWe strongly encourage maintainers of third-party Python projects to \nprepare their projects for 3.13 compatibilities during this phase, and \nwhere necessary publish Python 3.13 wheels on PyPI to be ready for the \nfinal release of 3.13.0. Any binary wheels built against Python \n3.13.0rc2 will work with future versions of Python 3.13. As always, \nreport any issues to the Python bug tracker.\nPlease keep in mind that this is a preview release and while it’s as close to the final release as we can get it, its use is not recommended for production environments.\nCore developers: time to work on documentation now\nAre all your changes properly documented?Are they mentioned in What’s New?Did you notice other changes you know of to have insufficient documentation?\nAs a reminder, until the final release of 3.13.0, the 3.13 branch is set up so that the Release Manager (@thomas) has to merge the changes. Please add him (@Yhg1s\n on GitHub) to any changes you think should go into 3.13.0. At this \npoint, unless something critical comes up, it should really be documentation only. Other changes (including tests) will be pushed to 3.13.1.\nNew features in Python 3.13\nA new and improved interactive interpreter, based on PyPy’s, featuring multi-line editing and color support, as well as colorized exception tracebacks.An experimental free-threaded build mode,\n which disables the Global Interpreter Lock, allowing threads to run \nmore concurrently. The build mode is available as an experimental \nfeature in the Windows and macOS installers as well.A preliminary, experimental JIT, providing the ground work for significant performance improvements.The locals() builtin function (and its C equivalent) now has well-defined semantics when mutating the returned mapping, which allows debuggers to operate more consistently.The (cyclic) garbage collector is now incremental, which should mean shorter pauses for collection in programs with a lot of objects.A modified version of mimalloc is now included, optional but enabled by default if supported by the platform, and required for the free-threaded build mode.Docstrings now have their leading indentation stripped, reducing memory use and the size of .pyc files. (Most tools handling docstrings already strip leading indentation.)The dbm module has a new dbm.sqlite3 backend that is used by default when creating new files.The minimum supported macOS version was changed from 10.9 to 10.13 (High Sierra). Older macOS versions will not be supported going forward.WASI is now a Tier 2 supported platform. Emscripten is no longer an officially supported platform (but Pyodide continues to support Emscripten).iOS is now a Tier 3 supported platform, with Android on the way as well.\nPython 3.12.6\nThis is an expedited release for 3.12 due to security content. The schedule returns back to regular programming in October.\nOne notable change for macOS users: as mentioned in the previous release of 3.12, this release drops support for macOS versions 10.9 through 10.12.\n Versions of macOS older than 10.13 haven’t been supported by Apple \nsince 2019, and maintaining support for them has become too difficult. \n(All versions of Python 3.13 have already dropped support for them.)\nGet it here: Python Release Python 3.12.6 | Python.org\n92 commits.\nPython 3.11.10\nPython 3.11 joins the eli ...
#  Summary(start_date=datetime.datetime(2024, 8, 5, 0, 0), prompt="Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-08-05 to 2024-08-11:\n\nPython 3.12.5 released: I'm pleased to announce the release of Python 3.12.5:https://www.python.org/downloads/release/python-3125/\xa0This is the fifth maintenance release of Python 3.12\nPython 3.12 is the newest major release of the Python programming \nlanguage, and it contains many new features and optimizations. 3.12.5 is\n the latest maintenance release, containing more than 250 bugfixes, \nbuild improvements and documentation changes since 3.12.4.This version of Python 3.12 also comes with pip 24.2 by default. However,\n due to an incompatibility with older macOS versions, macOS 10.9 through\n 10.12 will downgrade their version of pip to 24.1.2 during the \ninstallation process (in the Install Certificates step). See the installer ReadMe and the pip issue on the matter\n for more information. Versions of macOS older than 10.13 haven’t been \nsupported by Apple since 2019, and maintaining support for them is \nbecoming increasingly difficult. While this release of 3.12 still \nsupports them, it is likely that we will be forced to drop support for macOS 10.12 and older in a future 3.12 release. (Python 3.13 has already dropped support for them.)\xa0\n\xa0Major new features of the 3.12 series, compared to 3.11\n\xa0New features\nMore flexible f-string parsing, allowing many things previously disallowed (PEP 701).Support for the buffer protocol in Python code (PEP 688).A new debugging/profiling API (PEP 669).Support for isolated subinterpreters with separate Global Interpreter Locks (PEP 684).Even more improved error messages. More exceptions potentially caused by typos now make suggestions to the user.Support for the Linux perf profiler to report Python function names in traces.Many large and small performance improvements (like PEP 709 and support for the BOLT binary optimizer), delivering an estimated 5% overall performance improvement.\nType annotations\nNew type annotation syntax for generic classes (PEP 695).New override decorator for methods (PEP 698).\nDeprecations\nThe deprecated wstr and wstr_length members of the C implementation of unicode objects were removed, per PEP 623.In the unittest module, a number of long deprecated methods and classes were removed. (They had been deprecated since Python 3.1 or 3.2).The deprecated smtpd and distutils modules have been removed (see PEP 594 and PEP 632. The setuptools package continues to provide the distutils module.A number of other old, broken and deprecated functions, classes and methods have been removed.Invalid backslash escape sequences in strings now warn with SyntaxWarning instead of DeprecationWarning, making them more visible. (They will become syntax errors in the future.)The internal representation of integers has changed in preparation \nfor performance enhancements. (This should not affect most users as it \nis an internal detail, but it may cause problems for Cython-generated \ncode.)\nFor more details on the changes to Python 3.12, see What’s new in Python 3.12.\n\xa0More resources\nOnline Documentation.PEP 693, the Python 3.12 Release Schedule.Report bugs via GitHub Issues.Help fund Python directly or via GitHub Sponsors, and support the Python community.\n\xa0Enjoy the new releases\nThanks to all of the many volunteers who help make Python Development\n and these releases possible! Please consider supporting our efforts by \nvolunteering yourself or through organization contributions to the \nPython Software Foundation.\n\nYour release team,\nThomas Wouters \nŁukasz Langa \nNed Deily \nSteve Dower", summary='Python 3.12.5, the fifth maintenance release of Python 3.12, has been released. This version includes over 250 bug fixes, build improvements, and documentation changes since the previous release (3.12.4). Key highlights include:\n\n* **Improv ...
#  Summary(start_date=datetime.datetime(2024, 7, 29, 0, 0), prompt="Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-07-29 to 2024-08-04:\n\nPython 3.13.0 release candidate 1 released: I'm pleased to announce the release of Python 3.13 release candidate 1.https://www.python.org/downloads/release/python-3130rc1/\xa0This is the first release candidate of Python 3.13.0\nThis release, 3.13.0rc1, is the penultimate release \npreview. Entering the release candidate phase, only reviewed code \nchanges which are clear bug fixes are allowed between this release \ncandidate and the final release. The second candidate (and the last \nplanned release preview) is scheduled for Tuesday, 2024-09-03, while the\n official release of 3.13.0 is scheduled for Tuesday, 2024-10-01.\nThere will be no ABI changes from this point forward in the 3.13 series, and the goal is that there will be as few code changes as possible.\nCall to action\nWe strongly encourage maintainers of third-party Python projects to \nprepare their projects for 3.13 compatibilities during this phase, and \nwhere necessary publish Python 3.13 wheels on PyPI to be ready for the \nfinal release of 3.13.0. Any binary wheels built against Python \n3.13.0rc1 will work with future versions of Python 3.13. As always, report any issues to the Python bug tracker.\nPlease keep in mind that this is a preview release and while it’s as close to the final release as we can get it, its use is not recommended for production environments.\nCore developers: time to work on documentation now\nAre all your changes properly documented?Are they mentioned in What’s New?Did you notice other changes you know of to have insufficient documentation?\n\xa0Major new features of the 3.13 series, compared to 3.12\nSome of the new major new features and changes in Python 3.13 are:\nNew features\nA new and improved interactive interpreter, based on PyPy’s, featuring multi-line editing and color support, as well as colorized exception tracebacks.An experimental free-threaded build mode,\n which disables the Global Interpreter Lock, allowing threads to run \nmore concurrently. The build mode is available as an experimental \nfeature in the Windows and macOS installers as well.A preliminary, experimental JIT, providing the ground work for significant performance improvements.The locals() builtin function (and its C equivalent) now has well-defined semantics when mutating the returned mapping, which allows debuggers to operate more consistently.The (cyclic) garbage collector is now incremental, which should mean shorter pauses for collection in programs with a lot of objects.A modified version of mimalloc is now included, optional but enabled by default if supported by the platform, and required for the free-threaded build mode.Docstrings now have their leading indentation stripped, reducing memory use and the size of .pyc files. (Most tools handling docstrings already strip leading indentation.)The dbm module has a new dbm.sqlite3 backend that is used by default when creating new files.The minimum supported macOS version was changed from 10.9 to 10.13 (High Sierra). Older macOS versions will not be supported going forward.WASI is now a Tier 2 supported platform. Emscripten is no longer an officially supported platform (but Pyodide continues to support Emscripten).iOS is now a Tier 3 supported platform, with Android on the way as well.\nTyping\nSupport for type defaults in type parameters.A new type narrowing annotation, typing.TypeIs.A new annotation for read-only items in TypeDicts.A new annotation for marking deprecations in the type system.\nRemovals and new deprecations\nPEP 594 (Removing dead batteries from the standard library) scheduled removals of many deprecated modules: aifc, audioop, chunk, cgi, cgitb, crypt, imghdr, mailcap, msilib, nis, nntplib, ossaudiodev, pipes, sndhdr, spwd, sunau, telnetlib, uu, xdrlib, lib2to3.Many other rem ...
#  Summary(start_date=datetime.datetime(2024, 7, 15, 0, 0), prompt="Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-07-15 to 2024-07-21:\n\nPython 3.13.0 beta 4 released: I'm pleased to announce the release of Python 3.13 beta 4.https://www.python.org/downloads/release/python-3130b4/\n\xa0This is a beta preview of Python 3.13\nPython 3.13 is still in development.  This release, 3.13.0b4, is the final beta release preview of 3.13.\nBeta release previews are intended to give the wider community the \nopportunity to test new features and bug fixes and to prepare their \nprojects to support the new feature release.\nWe strongly encourage maintainers of third-party Python projects to test with 3.13 during the beta phase and report issues found to the Python bug tracker\n as soon as possible.  While the release is planned to be feature \ncomplete entering the beta phase, it is possible that features may be \nmodified or, in rare cases, deleted up until the start of the release \ncandidate phase (Tuesday 2024-07-30).  Our goal is to have no ABI changes\n after this final beta release, and as few code changes as possible \nafter 3.13.0rc1, the first release candidate.  To achieve that, it will \nbe extremely important to get as much exposure for 3.13 as possible during the beta phase.\nPlease keep in mind that this is a preview release and its use is not recommended for production environments.\n\xa0Major new features of the 3.13 series, compared to 3.12\nSome of the new major new features and changes in Python 3.13 are:\nNew features\nA new and improved interactive interpreter, based on PyPy’s, featuring multi-line editing and color support, as well as colorized exception tracebacks.An experimental free-threaded build mode,\n which disables the Global Interpreter Lock, allowing threads to run \nmore concurrently. The build mode is available as an experimental \nfeature in the Windows and macOS installers as well.A preliminary, experimental JIT, providing the ground work for significant performance improvements.The locals() builtin function (and its C equivalent) now has well-defined semantics when mutating the returned mapping, which allows debuggers to operate more consistently.The (cyclic) garbage collector is now incremental, which should mean shorter pauses for collection in programs with a lot of objects.A modified version of mimalloc is now included, optional but enabled by default if supported by the platform, and required for the free-threaded build mode.Docstrings now have their leading indentation stripped, reducing memory use and the size of .pyc files. (Most tools handling docstrings already strip leading indentation.)The dbm module has a new dbm.sqlite3 backend that is used by default when creating new files.The minimum supported macOS version was changed from 10.9 to 10.13 (High Sierra). Older macOS versions will not be supported going forward.WASI is now a Tier 2 supported platform. Emscripten is no longer an officially supported platform (but Pyodide continues to support Emscripten).\nTyping\nSupport for type defaults in type parameters.A new type narrowing annotation, typing.TypeIs.A new annotation for read-only items in TypeDicts.A new annotation for marking deprecations in the type system.\nRemovals and new deprecations\nPEP 594 (Removing dead batteries from the standard library) scheduled removals of many deprecated modules: aifc, audioop, chunk, cgi, cgitb, crypt, imghdr, mailcap, msilib, nis, nntplib, ossaudiodev, pipes, sndhdr, spwd, sunau, telnetlib, uu, xdrlib, lib2to3.Many other removals of deprecated classes, functions and methods in various standard library modules.C API removals and deprecations.  (Some removals present in alpha 1 were reverted in alpha 2, as the removals were deemed too disruptive at this time.)New deprecations, most of which are scheduled for removal from Python 3.15 or 3.16.\n(Hey, fellow core developer, if a feat ...
#  Summary(start_date=datetime.datetime(2024, 6, 24, 0, 0), prompt="Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-06-24 to 2024-06-30:\n\nPython 3.13.0 beta 3 released: I'm pleased to announce the release of Python 3.13 beta 3.https://www.python.org/downloads/release/python-3130b3/\xa0This is a beta preview of Python 3.13\nPython 3.13 is still in development.  This release, 3.13.0b3, is the third of four beta release previews of 3.13.\nBeta release previews are intended to give the wider community the \nopportunity to test new features and bug fixes and to prepare their \nprojects to support the new feature release.\nWe strongly encourage maintainers of third-party Python projects to test with 3.13 during the beta phase and report issues found to the Python bug tracker \n as soon as possible. While the release is planned to be feature \ncomplete entering the beta phase, it is possible that features may be \nmodified or, in rare cases, deleted up until the start of the release \ncandidate phase (Tuesday 2024-07-30). Our goal is to have no ABI changes\n after beta 4 and as few code changes as possible after 3.13.0rc1, the \nfirst release candidate. To achieve that, it will be extremely important to get as much exposure for 3.13 as possible during the beta phase.\xa0Please keep in mind that this is a preview release and its use is not recommended for production environments.\n\xa0Major new features of the 3.13 series, compared to 3.12\nSome of the new major new features and changes in Python 3.13 are:\nNew features\nA new and improved interactive interpreter , based on PyPy’s, featuring multi-line editing and color support, as well as colorized exception tracebacks .An experimental free-threaded build mode , which disables the Global Interpreter Lock, allowing threads to run more concurrently. The build mode is available as an experimental feature in the Windows and macOS installers as well.A preliminary, experimental JIT , providing the ground work for significant performance improvements.The (cyclic) garbage collector is now incremental , which should mean shorter pauses for collection in programs with a lot of objects.A modified version of mimalloc  is now included, optional but enabled by default if supported by the platform, and required for the free-threaded build mode.Docstrings now have their leading indentation stripped, reducing memory use and the size of .pyc files. (Most tools handling docstrings already strip leading indentation.)The dbm module  has a new dbm.sqlite3 backend  that is used by default when creating new files.The minimum supported macOS version was changed from 10.9 to 10.13 (High Sierra). Older macOS versions will not be supported going forward. \nTyping\nSupport for type defaults in type parameters.A new type narrowing annotation , typing.TypeIs.A new annotation for read-only items in TypeDicts .\nRemovals and new deprecations\nPEP 594 (Removing dead batteries from the standard library) scheduled removals of many deprecated modules: aifc, audioop, chunk, cgi, cgitb, crypt, imghdr, mailcap, msilib, nis, nntplib, ossaudiodev, pipes, sndhdr, spwd, sunau, telnetlib, uu, xdrlib, lib2to3.Many other removals  of deprecated classes, functions and methods in various standard library modules.C API removals and deprecations. (Some removals present in alpha 1 were reverted in alpha 2, as the removals were deemed too disruptive at this time.)New deprecations, most of which are scheduled for removal from Python 3.15 or 3.16.\n(Hey, fellow core developer, if a feature you find important is missing from this list, let Thomas know.)\nFor more details on the changes to Python 3.13, see What’s new in Python 3.13 . The next pre-release of Python 3.13 will be 3.13.0b4, currently scheduled for 2024-07-16.\n\xa0More resources\nOnline DocumentationPEP 719 , 3.13 Release ScheduleReport bugs at Issues · python/cpython · GitHub .Help fund Python directly ...
#  Summary(start_date=datetime.datetime(2024, 6, 3, 0, 0), prompt="Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-06-03 to 2024-06-09:\n\nPython 3.12.4 released: I'm pleased to announce the release of Python 3.12.4:https://www.python.org/downloads/release/python-3124/\xa0This is the third maintenance release of Python 3.12\nPython 3.12 is the newest major release of the Python programming \nlanguage, and it contains many new features and optimizations. 3.12.4 is\n the latest maintenance release, containing more than 250 bugfixes, \nbuild improvements and documentation changes since 3.12.3.\n\xa0Major new features of the 3.12 series, compared to 3.11\n\xa0New features\nMore flexible f-string parsing, allowing many things previously disallowed (PEP 701).Support for the buffer protocol in Python code (PEP 688).A new debugging/profiling API (PEP 669).Support for isolated subinterpreters with separate Global Interpreter Locks (PEP 684).Even more improved error messages. More exceptions potentially caused by typos now make suggestions to the user.Support for the Linux perf profiler to report Python function names in traces.Many large and small performance improvements (like PEP 709 and support for the BOLT binary optimizer), delivering an estimated 5% overall performance improvement.\nType annotations\nNew type annotation syntax for generic classes (PEP 695).New override decorator for methods (PEP 698).\nDeprecations\nThe deprecated wstr and wstr_length members of the C implementation of unicode objects were removed, per PEP 623.In the unittest module, a number of long deprecated methods and classes were removed. (They had been deprecated since Python 3.1 or 3.2).The deprecated smtpd and distutils modules have been removed (see PEP 594 and PEP 632. The setuptools package continues to provide the distutils module.A number of other old, broken and deprecated functions, classes and methods have been removed.Invalid backslash escape sequences in strings now warn with SyntaxWarning instead of DeprecationWarning, making them more visible. (They will become syntax errors in the future.)The internal representation of integers has changed in preparation \nfor performance enhancements. (This should not affect most users as it \nis an internal detail, but it may cause problems for Cython-generated \ncode.)\nFor more details on the changes to Python 3.12, see What’s new in Python 3.12.\n\xa0More resources\nOnline Documentation.PEP 693, the Python 3.12 Release Schedule.Report bugs via GitHub Issues.Help fund Python directly or via GitHub Sponsors, and support the Python community.\n\xa0Enjoy the new releases\nThanks to all of the many volunteers who help make Python Development\n and these releases possible! Please consider supporting our efforts by \nvolunteering yourself or through organization contributions to the \nPython Software Foundation.\n\nYour release team,\nThomas Wouters \nŁukasz Langa \nNed Deily \nSteve Dower \nPython 3.13.0 beta 2 released: I'm pleased to announce the release of Python 3.13 beta 2.https://www.python.org/downloads/release/python-3130b2/\xa0This is a beta preview of Python 3.13\nPython 3.13 is still in development. This release, 3.13.0b2, is the second of four beta release previews of 3.13.\nBeta release previews are intended to give the wider community the \nopportunity to test new features and bug fixes and to prepare their \nprojects to support the new feature release.\nWe strongly encourage maintainers of third-party Python projects to test with 3.13 during the beta phase and report issues found to the Python bug tracker \n as soon as possible. While the release is planned to be feature \ncomplete entering the beta phase, it is possible that features may be \nmodified or, in rare cases, deleted up until the start of the release \ncandidate phase (Tuesday 2024-07-30). Our goal is to have no ABI changes\n after beta 4 and as few code change ...
#  Summary(start_date=datetime.datetime(2024, 5, 6, 0, 0), prompt="Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-05-06 to 2024-05-12:\n\nPython 3.13.0 beta 1 released: I'm pleased to announce the release of Python 3.13 beta 1 (and feature freeze for Python 3.13).https://www.python.org/downloads/release/python-3130b1/\xa0This is a beta preview of Python 3.13\nPython 3.13 is still in development. This release, 3.13.0b1, is the first of four beta release previews of 3.13.\nBeta release previews are intended to give the wider community the \nopportunity to test new features and bug fixes and to prepare their \nprojects to support the new feature release.\nWe strongly encourage maintainers of third-party Python projects to test with 3.13 during the beta phase and report issues found to the Python bug tracker\n as soon as possible. While the release is planned to be feature \ncomplete entering the beta phase, it is possible that features may be \nmodified or, in rare cases, deleted up until the start of the release \ncandidate phase (Tuesday 2024-07-30). Our goal is to have no ABI changes\n after beta 4 and as few code changes as possible after 3.13.0rc1, the \nfirst release candidate. To achieve that, it will be extremely important to get as much exposure for 3.13 as possible during the beta phase.\nPlease keep in mind that this is a preview release and its use is not recommended for production environments.\nMajor new features of the 3.13 series, compared to 3.12\nSome of the new major new features and changes in Python 3.13 are:\nNew features\nA new and improved interactive interpreter, based on PyPy’s, featuring multi-line editing and color support, as well as colorized exception tracebacks.An experimental free-threaded build mode, which disables the Global Interpreter Lock, allowing threads to run more concurrently.A preliminary, experimental JIT, providing the ground work for significant performance improvements.The (cyclic) garbage collector is now incremental, which should mean shorter pauses for collection in programs with a lot of objects.A modified version of mimalloc is now included, optional but enabled by default if supported by the platform, and required for the free-threaded build mode.Docstrings now have their leading indentation stripped, reducing memory use and the size of .pyc files. (Most tools handling docstrings already strip leading indentation.)The dbm module has a new dbm.sqlite3 backend that is used by default when creating new files.\nTyping\nSupport for type defaults in type parameters.A new type narrowing annotation, typing.TypeIs.A new annotation for read-only items in TypeDicts.\nRemovals and new deprecations\nPEP 594 (Removing dead batteries from the standard library) scheduled removals of many deprecated modules: aifc, audioop, chunk, cgi, cgitb, crypt, imghdr, mailcap, msilib, nis, nntplib, ossaudiodev, pipes, sndhdr, spwd, sunau, telnetlib, uu, xdrlib, lib2to3.Many other removals of deprecated classes, functions and methods in various standard library modules.C API removals and deprecations. (Some removals present in alpha 1 were reverted in alpha 2, as the removals were deemed too disruptive at this time.)New deprecations, most of which are scheduled for removal from Python 3.15 or 3.16.\n(Hey, fellow core developer, if a feature you find important is missing from this list, let Thomas know.)\nFor more details on the changes to Python 3.13, see What’s new in Python 3.13. The next pre-release of Python 3.13 will be 3.13.0b2, currently scheduled for 2024-05-28.\n\xa0More resources\nOnline DocumentationPEP 719, 3.13 Release ScheduleReport bugs at Issues · python/cpython · GitHub.Help fund Python directly (or via GitHub Sponsors), and support the Python community. \n\xa0Enjoy the new releases\nThanks to all of the many volunteers who help make Python Development\n and these releases possible! Please consider supporting our eff ...
#  Summary(start_date=datetime.datetime(2024, 4, 8, 0, 0), prompt='Provide a neutral summary in English that focuses on key points. The summary should be medium in length.\n\nNews from 2024-04-08 to 2024-04-14:\n\nPython 3.12.3 and 3.13.0a6 released: It’s time to eclipse the Python 3.11.9 release with two releases, one of which is the very last alpha release of Python 3.13:\xa0\nPython 3.12.3\n300+ of the finest commits went into this latest maintenance release \nof the latest Python version, the most stablest, securest, bugfreeest we\n could make it.https://www.python.org/downloads/release/python-3123/\xa0\n\n\n\n\n\nPython 3.13.0a6\nWhat’s that? The last alpha release? Just one more month until \nfeature freeze! Get your features done, get your bugs fixed, let’s get \n3.13.0 ready for people to actually use! Until then, let’s test with \nalpha 6. The highlights of 3.13 you ask? Well:\nIn the interactive interpreter, exception tracebacks are now colorized by default.A preliminary, experimental JIT was added, providing the ground work for significant performance improvements.The (cyclic) garbage collector is now incremental, which should mean shorter pauses for collection in programs with a lot of objects.Docstrings now have their leading indentation stripped, reducing memory use and the size of .pyc files. (Most tools handling docstrings already strip leading indentation.)The dbm module has a new dbm.sqlite3 backend that is used by default when creating new files.PEP 594 (Removing dead batteries from the standard library) scheduled removals of many deprecated modules: aifc, audioop, chunk, cgi, cgitb, crypt, imghdr, mailcap, msilib, nis, nntplib, ossaudiodev, pipes, sndhdr, spwd, sunau, telnetlib, uu, xdrlib, lib2to3.Many other removals of deprecated classes, functions and methods in various standard library modules.New deprecations, most of which are scheduled for removal from Python 3.15 or 3.16.C API removals and deprecations. (Some removals present in alpha 1 were reverted in alpha 2, as the removals were deemed too disruptive at this time.)\n(Hey, fellow core developer, if a feature you find important is missing from this list, let Thomas know. It’s getting to be really important now!)\nhttps://www.python.org/downloads/release/python-3130a6/\xa0\xa0\n\n\n\nWe hope you enjoy the new releases!\nThanks to all of the many volunteers who help make Python Development\n and these releases possible! Please consider supporting our efforts by \nvolunteering yourself, or through contributions to the Python Software Foundation  or CPython itself.\nThomas “can you tell I haven’t had coffee today” Wouters \non behalf of your release team,\nNed Deily \nSteve Dower \nPablo Galindo Salgado \nŁukasz Langa \nPython 3.11.9 is now available: This is the last bug fix release of Python 3.11\xa0This is the ninth maintenance release of Python 3.11Python 3.11.9 is the newest major release of the Python programming language, and it contains many new features and optimizations. Get it here:https://www.python.org/downloads/release/python-3119/Major new features of the 3.11 series, compared to 3.10Among the new major new features and changes so far:PEP 657\xa0– Include Fine-Grained Error Locations in TracebacksPEP 654\xa0– Exception Groups and except*PEP 673\xa0– Self TypePEP 646\xa0– Variadic GenericsPEP 680\xa0– tomllib: Support for Parsing TOML in the Standard LibraryPEP 675\xa0– Arbitrary Literal String TypePEP 655\xa0– Marking individual TypedDict items as required or potentially-missingbpo-46752\xa0– Introduce task groups to asyncioPEP 681\xa0– Data Class Transformsbpo-433030– Atomic grouping ((?>…)) and possessive quantifiers (*+, ++, ?+, {m,n}+) are now supported in regular expressions.The\xa0Faster Cpython Project\xa0is already yielding some exciting results. Python 3.11 is up to 10-60% faster than Python 3.10. On average, we measured a 1.22x speedup on the standard benchmark suite. See\xa0Faster CPython for details.More resourcesOnline Docume ...
# ...
#
#
#  33%|███▎      | 252/768 [00:14<00:29, 17.49it/s]
#
#
#  33%|███▎      | 254/768 [00:14<00:29, 17.63it/s]
#
#
#  33%|███▎      | 256/768 [00:14<00:29, 17.45it/s]
#
#
#  34%|███▎      | 258/768 [00:14<00:29, 17.26it/s]
#
#
#  34%|███▍      | 260/768 [00:15<00:29, 17.18it/s]
#  34%|███▍      | 262/768 [00:15<00:29, 17.37it/s]
#
#
#
#
#  34%|███▍      | 264/768 [00:15<00:29, 17.02it/s]
#  35%|███▍      | 266/768 [00:15<00:29, 17.14it/s]
#
#
#  35%|███▍      | 268/768 [00:15<00:28, 17.25it/s]
#
#
#
#
#  35%|███▌      | 270/768 [00:15<00:28, 17.25it/s]
#  35%|███▌      | 272/768 [00:15<00:31, 15.92it/s]
#
#
#  36%|███▌      | 274/768 [00:15<00:31, 15.83it/s]
#
#
#  36%|███▌      | 276/768 [00:16<00:30, 16.17it/s]
#
#
#  36%|███▌      | 278/768 [00:16<00:29, 16.50it/s]
#
#
#  36%|███▋      | 280/768 [00:16<00:29, 16.68it/s]
#
#
#  37%|███▋      | 282/768 [00:16<00:28, 16.98it/s]
#
#
#  37%|███▋      | 284/768 [00:16<00:28, 16.90it/s]
#
#
#  37%|███▋      | 286/768 [00:16<00:28, 17.08it/s]
#
#
#  38%|███▊      | 288/768 [00:16<00:27, 17.17it/s]
#
#
#  38%|███▊      | 290/768 [00:16<00:27, 17.23it/s]
#
#
#  38%|███▊      | 292/768 [00:16<00:28, 16.46it/s]
#
#
#  38%|███▊      | 294/768 [00:17<00:28, 16.71it/s]
#
#
#  39%|███▊      | 296/768 [00:17<00:28, 16.44it/s]
#
#
#  39%|███▉      | 298/768 [00:17<00:28, 16.28it/s]
#
#
#  39%|███▉      | 300/768 [00:17<00:29, 16.02it/s]
#
#
#  39%|███▉      | 302/768 [00:17<00:28, 16.28it/s]
#
#
#  40%|███▉      | 304/768 [00:17<00:28, 16.22it/s]
#
#
#
#
#  40%|███▉      | 306/768 [00:17<00:28, 16.45it/s]
#
#
#  40%|████      | 308/768 [00:17<00:27, 16.88it/s]
#
#
#  40%|████      | 310/768 [00:18<00:26, 17.30it/s]
#  41%|████      | 312/768 [00:18<00:25, 17.66it/s]
#
#
#
#
#  41%|████      | 314/768 [00:18<00:25, 17.69it/s]
#  41%|████      | 316/768 [00:18<00:25, 17.63it/s]
#
#
#  41%|████▏     | 318/768 [00:18<00:25, 17.85it/s]
#
#
#  42%|████▏     | 320/768 [00:18<00:25, 17.69it/s]
#
#
#  42%|████▏     | 322/768 [00:18<00:25, 17.63it/s]
#
#
#  42%|████▏     | 324/768 [00:18<00:25, 17.59it/s]
#
#
#  42%|████▏     | 326/768 [00:18<00:25, 17.55it/s]
#
#
#  43%|████▎     | 328/768 [00:19<00:26, 16.74it/s]
#
#
#  43%|████▎     | 330/768 [00:19<00:25, 16.90it/s]
#
#
#  43%|████▎     | 332/768 [00:19<00:25, 16.93it/s]
#
#
#  43%|████▎     | 334/768 [00:19<00:25, 17.00it/s]
#
#
#  44%|████▍     | 336/768 [00:19<00:25, 17.14it/s]
#
#
#  44%|████▍     | 338/768 [00:19<00:25, 16.99it/s]
#
#
#  44%|████▍     | 340/768 [00:19<00:25, 16.86it/s]
#
#
#  45%|████▍     | 342/768 [00:19<00:24, 17.16it/s]
#
#
#  45%|████▍     | 344/768 [00:20<00:24, 17.25it/s]
#
#
#  45%|████▌     | 346/768 [00:20<00:24, 17.12it/s]
#
#
#  45%|████▌     | 348/768 [00:20<00:23, 17.53it/s]
#
#
#  46%|████▌     | 350/768 [00:20<00:24, 17.30it/s]
#
#
#  46%|████▌     | 352/768 [00:20<00:24, 16.67it/s]
#
#
#  46%|████▌     | 354/768 [00:20<00:24, 16.72it/s]
#
#
#  46%|████▋     | 356/768 [00:20<00:24, 16.61it/s]
#
#
#  47%|████▋     | 358/768 [00:20<00:24, 16.69it/s]
#
#
#  47%|████▋     | 360/768 [00:20<00:24, 16.74it/s]
#
#
#  47%|████▋     | 362/768 [00:21<00:24, 16.55it/s]
#
#
#  47%|████▋     | 364/768 [00:21<00:24, 16.50it/s]
#
#
#  48%|████▊     | 366/768 [00:21<00:24, 16.50it/s]
#
#
#  48%|████▊     | 368/768 [00:21<00:23, 16.75it/s]
#
#
#  48%|████▊     | 370/768 [00:21<00:26, 15.19it/s]
#
#
#  48%|████▊     | 372/768 [00:21<00:24, 16.01it/s]
#
#
#  49%|████▊     | 374/768 [00:21<00:23, 16.46it/s]
#
#
#  49%|████▉     | 376/768 [00:21<00:23, 16.43it/s]
#
#
#  49%|████▉     | 378/768 [00:22<00:23, 16.31it/s]
#
#
#  49%|████▉     | 380/768 [00:22<00:23, 16.29it/s]
#
#
#  50%|████▉     | 382/768 [00:22<00:23, 16.43it/s]
#
#
#  50%|█████     | 384/768 [00:22<00:23, 16.64it/s]
#
#
#  50%|█████     | 386/768 [00:22<00:22, 17.29it/s]
#
#
#  51%|█████     | 388/768 [00:22<00:22, 17.03it/s]
#
#
#  51%|█████     | 390/768 [00:22<00:21, 17.34it/s]
#
#
#  51%|█████     | 392/768 [00:22<00:21, 17.52it/s]
#
#
#  51%|█████▏    | 394/768 [00:23<00:21, 17.58it/s]
#
#
#  52%|█████▏    | 396/768 [00:23<00:21, 17.41it/s]
#
#
#  52%|█████▏    | 398/768 [00:23<00:21, 17.57it/s]
#
#
#  52%|█████▏    | 400/768 [00:23<00:20, 17.56it/s]
#
#
#  52%|█████▏    | 402/768 [00:23<00:21, 17.41it/s]
#
#
#  53%|█████▎    | 404/768 [00:23<00:21, 17.30it/s]
#
#
#  53%|█████▎    | 406/768 [00:23<00:20, 17.26it/s]
#
#
#  53%|█████▎    | 408/768 [00:23<00:21, 16.98it/s]
#
#
#  53%|█████▎    | 410/768 [00:23<00:21, 16.66it/s]
#
#
#  54%|█████▎    | 412/768 [00:24<00:21, 16.78it/s]
#
#
#  54%|█████▍    | 414/768 [00:24<00:21, 16.41it/s]
#
#
#  54%|█████▍    | 416/768 [00:24<00:23, 15.11it/s]
#
#
#  54%|█████▍    | 418/768 [00:24<00:22, 15.39it/s]
#
#
#  55%|█████▍    | 420/768 [00:24<00:21, 15.85it/s]
#
#
#  55%|█████▍    | 422/768 [00:24<00:21, 16.21it/s]
#
#
#  55%|█████▌    | 424/768 [00:24<00:20, 16.48it/s]
#
#
#  55%|█████▌    | 426/768 [00:24<00:20, 16.81it/s]
#
#
#  56%|█████▌    | 428/768 [00:25<00:20, 16.81it/s]
#
#
#  56%|█████▌    | 430/768 [00:25<00:20, 16.48it/s]
#
#
#  56%|█████▋    | 432/768 [00:25<00:20, 16.62it/s]
#
#
#  57%|█████▋    | 434/768 [00:25<00:19, 16.74it/s]
#
#
#  57%|█████▋    | 436/768 [00:25<00:19, 16.68it/s]
#
#
#  57%|█████▋    | 438/768 [00:25<00:19, 16.72it/s]
#
#
#  57%|█████▋    | 440/768 [00:25<00:19, 16.54it/s]
#
#
#  58%|█████▊    | 442/768 [00:25<00:19, 16.58it/s]
#
#
#  58%|█████▊    | 444/768 [00:26<00:19, 16.55it/s]
#
#
#  58%|█████▊    | 446/768 [00:26<00:19, 16.39it/s]
#
#
#  58%|█████▊    | 448/768 [00:26<00:19, 16.52it/s]
#
#
#  59%|█████▊    | 450/768 [00:26<00:19, 16.63it/s]
#
#
#  59%|█████▉    | 452/768 [00:26<00:18, 16.77it/s]
#
#
#  59%|█████▉    | 454/768 [00:26<00:18, 16.85it/s]
#
#
#  59%|█████▉    | 456/768 [00:26<00:18, 17.19it/s]
#
#
#  60%|█████▉    | 458/768 [00:26<00:20, 15.26it/s]
#
#
#  60%|█████▉    | 460/768 [00:27<00:19, 15.81it/s]
#
#
#  60%|██████    | 462/768 [00:27<00:19, 16.04it/s]
#
#
#  60%|██████    | 464/768 [00:27<00:18, 16.49it/s]
#
#
#  61%|██████    | 466/768 [00:27<00:18, 16.58it/s]
#
#
#  61%|██████    | 468/768 [00:27<00:18, 16.60it/s]
#
#
#  61%|██████    | 470/768 [00:27<00:17, 16.88it/s]
#
#
#  61%|██████▏   | 472/768 [00:27<00:17, 17.01it/s]
#
#
#  62%|██████▏   | 474/768 [00:27<00:17, 16.87it/s]
#
#
#  62%|██████▏   | 476/768 [00:27<00:17, 16.70it/s]
#
#
#  62%|██████▏   | 478/768 [00:28<00:17, 16.50it/s]
#
#
#  62%|██████▎   | 480/768 [00:28<00:17, 16.22it/s]
#
#
#  63%|██████▎   | 482/768 [00:28<00:17, 16.37it/s]
#
#
#  63%|██████▎   | 484/768 [00:28<00:17, 16.46it/s]
#
#
#  63%|██████▎   | 486/768 [00:28<00:17, 16.42it/s]
#
#
#  64%|██████▎   | 488/768 [00:28<00:17, 16.18it/s]
#
#
#  64%|██████▍   | 490/768 [00:28<00:16, 16.51it/s]
#
#
#
# 100%|██████████| 488/488 [00:28<00:00, 16.91it/s]
#
#  64%|██████▍   | 492/768 [00:28<00:18, 14.95it/s]
#
#
#
#  65%|██████▍   | 496/768 [00:29<00:16, 16.47it/s]
#
#  65%|██████▍   | 498/768 [00:29<00:15, 17.05it/s]
#
#  65%|██████▌   | 500/768 [00:29<00:15, 17.26it/s]
#
#  65%|██████▌   | 502/768 [00:29<00:15, 17.50it/s]
#
#  66%|██████▌   | 504/768 [00:29<00:16, 15.97it/s]
#
#  66%|██████▌   | 506/768 [00:29<00:16, 16.19it/s]
#
#  66%|██████▌   | 508/768 [00:29<00:15, 16.56it/s]
#
#  66%|██████▋   | 510/768 [00:30<00:15, 16.48it/s]
#
#  67%|██████▋   | 512/768 [00:30<00:15, 16.63it/s]
#
#  67%|██████▋   | 514/768 [00:30<00:15, 16.73it/s]
#
#  67%|██████▋   | 516/768 [00:30<00:15, 16.76it/s]
#
#  67%|██████▋   | 518/768 [00:30<00:14, 16.90it/s]
#
#  68%|██████▊   | 520/768 [00:30<00:14, 16.99it/s]
#
#  68%|██████▊   | 522/768 [00:30<00:14, 17.24it/s]
#
#  68%|██████▊   | 524/768 [00:30<00:14, 17.07it/s]
#
#  68%|██████▊   | 526/768 [00:30<00:14, 17.10it/s]
#
#  69%|██████▉   | 528/768 [00:31<00:14, 16.80it/s]
#
#  69%|██████▉   | 530/768 [00:31<00:14, 16.86it/s]
#
#  69%|██████▉   | 532/768 [00:31<00:13, 17.02it/s]
#
#  70%|██████▉   | 534/768 [00:31<00:13, 17.01it/s]
#
#  70%|██████▉   | 536/768 [00:31<00:13, 17.29it/s]
#
#  70%|███████   | 538/768 [00:31<00:13, 17.31it/s]
#
#  70%|███████   | 540/768 [00:31<00:12, 17.56it/s]
#
#  71%|███████   | 542/768 [00:31<00:12, 17.81it/s]
#
#  71%|███████   | 544/768 [00:32<00:12, 17.67it/s]
#
#  71%|███████   | 546/768 [00:32<00:12, 17.49it/s]
#
#  71%|███████▏  | 548/768 [00:32<00:12, 17.47it/s]
#
#
#  72%|███████▏  | 550/768 [00:32<00:12, 17.28it/s]
#
#  72%|███████▏  | 552/768 [00:32<00:12, 17.22it/s]
#
#  72%|███████▏  | 554/768 [00:32<00:11, 17.93it/s]
#
#  72%|███████▏  | 556/768 [00:32<00:12, 16.50it/s]
#
#  73%|███████▎  | 558/768 [00:32<00:12, 16.47it/s]
#
#  73%|███████▎  | 560/768 [00:32<00:12, 16.56it/s]
#
#  73%|███████▎  | 562/768 [00:33<00:12, 16.62it/s]
#
#  73%|███████▎  | 564/768 [00:33<00:12, 16.76it/s]
#
#  74%|███████▎  | 566/768 [00:33<00:11, 16.89it/s]
#
#  74%|███████▍  | 568/768 [00:33<00:11, 16.94it/s]
#
#  74%|███████▍  | 570/768 [00:33<00:11, 16.82it/s]
#
#  74%|███████▍  | 572/768 [00:33<00:11, 16.68it/s]
#
#  75%|███████▍  | 574/768 [00:33<00:11, 16.86it/s]
#
#  75%|███████▌  | 576/768 [00:33<00:11, 17.00it/s]
#
#  75%|███████▌  | 578/768 [00:34<00:11, 17.03it/s]
#
#  76%|███████▌  | 580/768 [00:34<00:11, 16.93it/s]
#
#  76%|███████▌  | 582/768 [00:34<00:11, 16.89it/s]
#
#  76%|███████▌  | 584/768 [00:34<00:10, 16.84it/s]
#
#  76%|███████▋  | 586/768 [00:34<00:10, 16.79it/s]
#
#
#
# 100%|██████████| 585/585 [00:34<00:00, 16.93it/s]
#
#
# 100%|██████████| 598/598 [00:35<00:00, 16.97it/s]
#  79%|███████▉  | 607/768 [00:35<00:07, 20.13it/s]
# 100%|██████████| 639/639 [00:37<00:00, 17.21it/s]
#   0%|          | 0/32 [00:00<?, ?it/s]
#
#
#   3%|▎         | 1/32 [00:02<01:23,  2.69s/it]
#
#
#   6%|▋         | 2/32 [00:05<01:20,  2.68s/it]
#
#
#   9%|▉         | 3/32 [00:08<01:17,  2.67s/it]
#
#
#  12%|█▎        | 4/32 [00:10<01:14,  2.67s/it]
#
#
#  16%|█▌        | 5/32 [00:13<01:11,  2.66s/it]
#
#
#  19%|█▉        | 6/32 [00:16<01:09,  2.67s/it]
#
#
#  22%|██▏       | 7/32 [00:18<01:06,  2.67s/it]
#
#
#  25%|██▌       | 8/32 [00:21<01:03,  2.66s/it]
#
#
#  28%|██▊       | 9/32 [00:23<01:00,  2.65s/it]
#
#
#  31%|███▏      | 10/32 [00:26<00:58,  2.66s/it]
#
#
#  34%|███▍      | 11/32 [00:29<00:55,  2.65s/it]
#
#
#  38%|███▊      | 12/32 [00:31<00:53,  2.65s/it]
#
#
#  41%|████      | 13/32 [00:34<00:50,  2.66s/it]
#
#
#  44%|████▍     | 14/32 [00:37<00:47,  2.66s/it]
#
#
#  47%|████▋     | 15/32 [00:39<00:45,  2.66s/it]
#
#
#  50%|█████     | 16/32 [00:42<00:42,  2.67s/it]
#
#
#  53%|█████▎    | 17/32 [00:45<00:40,  2.67s/it]
#
#
#  56%|█████▋    | 18/32 [00:47<00:37,  2.67s/it]
#
#
#  59%|█████▉    | 19/32 [00:50<00:34,  2.69s/it]
#
#
#  62%|██████▎   | 20/32 [00:53<00:32,  2.70s/it]
#
#
#  66%|██████▌   | 21/32 [00:56<00:29,  2.70s/it]
#
#
#
# 100%|██████████| 25/25 [01:06<00:00,  2.67s/it]
#  69%|██████▉   | 22/32 [00:58<00:27,  2.72s/it]
#
# /home/timur/radiozilla/.venv/lib/python3.12/site-packages/bark/generation.py:175: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with InferenceContext(), torch.inference_mode(), torch.no_grad(), autocast():
#
#
#
#
#  72%|███████▏  | 23/32 [01:02<00:27,  3.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  75%|███████▌  | 24/32 [01:05<00:23,  2.99s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  78%|███████▊  | 25/32 [01:08<00:20,  2.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  81%|████████▏ | 26/32 [01:11<00:17,  2.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  84%|████████▍ | 27/32 [01:13<00:14,  2.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  88%|████████▊ | 28/32 [01:16<00:11,  2.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 30/30 [01:20<00:00,  2.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  91%|█████████ | 29/32 [01:19<00:08,  2.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 30/30 [01:22<00:00,  2.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  94%|█████████▍| 30/32 [01:22<00:05,  2.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  97%|█████████▋| 31/32 [01:25<00:02,  2.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 32/32 [01:28<00:00,  2.78s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#   0%|          | 0/768 [00:00<?, ?it/s]
#
#
#   0%|          | 1/768 [00:00<01:47,  7.13it/s]
#
#
#   0%|          | 3/768 [00:00<00:57, 13.20it/s]
#
#
#   1%|          | 5/768 [00:00<00:48, 15.69it/s]
#
#
#   1%|          | 7/768 [00:00<00:46, 16.50it/s]
#
#
#   1%|          | 9/768 [00:00<00:44, 17.10it/s]
#
#
#   1%|▏         | 11/768 [00:00<00:43, 17.47it/s]
#
#
#   2%|▏         | 13/768 [00:00<00:42, 17.91it/s]
#
#
#   2%|▏         | 15/768 [00:00<00:42, 17.83it/s]
#
#
#   2%|▏         | 17/768 [00:01<00:42, 17.80it/s]
#
#
#   2%|▏         | 19/768 [00:01<00:41, 17.89it/s]
#
#
#   3%|▎         | 21/768 [00:01<00:41, 18.03it/s]
#
#
#   3%|▎         | 23/768 [00:01<00:41, 18.05it/s]
#
#
#   3%|▎         | 25/768 [00:01<00:40, 18.16it/s]
#
#
#   4%|▎         | 27/768 [00:01<00:41, 17.73it/s]
#
#
#   4%|▍         | 29/768 [00:01<00:41, 17.69it/s]
#
#
#   4%|▍         | 31/768 [00:01<00:41, 17.65it/s]
#
#
#   4%|▍         | 33/768 [00:01<00:40, 18.00it/s]
#
#
#   5%|▍         | 35/768 [00:02<00:41, 17.74it/s]
#
#
#   5%|▍         | 37/768 [00:02<00:44, 16.28it/s]
#
#
#   5%|▌         | 39/768 [00:02<00:42, 17.10it/s]
#
#
#   5%|▌         | 41/768 [00:02<00:41, 17.51it/s]
#
#
#   6%|▌         | 43/768 [00:02<00:40, 18.09it/s]
#
#
#   6%|▌         | 45/768 [00:02<00:39, 18.46it/s]
#
#
#   6%|▌         | 47/768 [00:02<00:39, 18.20it/s]
#
#
#   6%|▋         | 49/768 [00:02<00:38, 18.44it/s]
# 100%|██████████| 599/599 [00:30<00:00, 19.88it/s]
#
#
#
#   7%|▋         | 51/768 [00:02<00:43, 16.60it/s]
#
#   7%|▋         | 53/768 [00:03<00:41, 17.17it/s]
#
#   7%|▋         | 55/768 [00:03<00:42, 16.85it/s]
#
#   7%|▋         | 57/768 [00:03<00:42, 16.67it/s]
#
#   8%|▊         | 59/768 [00:03<00:43, 16.47it/s]
#
#   8%|▊         | 61/768 [00:03<00:40, 17.30it/s]
#
#   8%|▊         | 63/768 [00:03<00:39, 17.80it/s]
#
#   8%|▊         | 65/768 [00:03<00:38, 18.34it/s]
#
#   9%|▉         | 68/768 [00:03<00:36, 19.20it/s]
#
#   9%|▉         | 70/768 [00:03<00:36, 19.18it/s]
#
#   9%|▉         | 72/768 [00:04<00:36, 19.14it/s]
#
#  10%|▉         | 74/768 [00:04<00:40, 17.07it/s]
#
#
#
#  10%|█         | 77/768 [00:04<00:37, 18.20it/s]
#
#  10%|█         | 79/768 [00:04<00:37, 18.54it/s]
#
#  11%|█         | 82/768 [00:04<00:35, 19.11it/s]
#
#  11%|█         | 85/768 [00:04<00:34, 19.59it/s]
#
#  11%|█▏        | 87/768 [00:04<00:34, 19.49it/s]
#
#  12%|█▏        | 89/768 [00:04<00:35, 19.36it/s]
#
#  12%|█▏        | 91/768 [00:05<00:34, 19.40it/s]
#
#  12%|█▏        | 93/768 [00:05<00:34, 19.54it/s]
#
#  12%|█▏        | 95/768 [00:05<00:34, 19.55it/s]
#
#  13%|█▎        | 97/768 [00:05<00:34, 19.42it/s]
#
#  13%|█▎        | 99/768 [00:05<00:34, 19.15it/s]
#
#  13%|█▎        | 101/768 [00:05<00:34, 19.07it/s]
#
#
#
#  14%|█▎        | 104/768 [00:05<00:34, 19.53it/s]
#
#  14%|█▍        | 106/768 [00:05<00:34, 19.45it/s]
#
#
#  14%|█▍        | 109/768 [00:06<00:34, 19.26it/s]
#
#  14%|█▍        | 111/768 [00:06<00:34, 19.18it/s]
#
#  15%|█▍        | 113/768 [00:06<00:34, 19.06it/s]
#
#  15%|█▍        | 115/768 [00:06<00:34, 18.87it/s]
#
#  15%|█▌        | 117/768 [00:06<00:34, 19.09it/s]
#
#  15%|█▌        | 119/768 [00:06<00:34, 19.06it/s]
#
#  16%|█▌        | 121/768 [00:06<00:37, 17.16it/s]
#
#  16%|█▌        | 123/768 [00:06<00:36, 17.71it/s]
#
#  16%|█▋        | 126/768 [00:06<00:34, 18.51it/s]
#
#  17%|█▋        | 128/768 [00:07<00:34, 18.46it/s]
#
#  17%|█▋        | 130/768 [00:07<00:35, 17.77it/s]
#
#  17%|█▋        | 132/768 [00:07<00:35, 17.97it/s]
#
#  17%|█▋        | 134/768 [00:07<00:34, 18.13it/s]
#
#  18%|█▊        | 136/768 [00:07<00:34, 18.51it/s]
#
#  18%|█▊        | 138/768 [00:07<00:33, 18.72it/s]
#
#  18%|█▊        | 140/768 [00:07<00:33, 18.52it/s]
#
#  18%|█▊        | 142/768 [00:07<00:33, 18.79it/s]
#
#  19%|█▉        | 144/768 [00:07<00:32, 18.91it/s]
#
#  19%|█▉        | 146/768 [00:08<00:32, 19.00it/s]
#
#  19%|█▉        | 148/768 [00:08<00:32, 19.07it/s]
#
#  20%|█▉        | 150/768 [00:08<00:32, 18.90it/s]
#
#  20%|█▉        | 152/768 [00:08<00:32, 19.05it/s]
#
#  20%|██        | 154/768 [00:08<00:32, 19.00it/s]
#
#  20%|██        | 157/768 [00:08<00:31, 19.53it/s]
#
#  21%|██        | 159/768 [00:08<00:31, 19.10it/s]
#
#  21%|██        | 161/768 [00:08<00:31, 19.27it/s]
#
#  21%|██        | 163/768 [00:08<00:33, 17.88it/s]
#
#  21%|██▏       | 165/768 [00:09<00:33, 18.18it/s]
#
#
#  22%|██▏       | 167/768 [00:09<00:32, 18.32it/s]
#
#
#
# 100%|██████████| 374/374 [00:20<00:00, 18.70it/s]
#
#
# 100%|██████████| 210/210 [00:11<00:00, 18.54it/s]
#   0%|          | 0/11 [00:00<?, ?it/s]
#
#
#   9%|▉         | 1/11 [00:02<00:28,  2.80s/it]
#
#
#  18%|█▊        | 2/11 [00:05<00:25,  2.79s/it]
#
#
#  27%|██▋       | 3/11 [00:08<00:22,  2.80s/it]
#
#
#  36%|███▋      | 4/11 [00:11<00:19,  2.83s/it]
#
#
#  45%|████▌     | 5/11 [00:14<00:17,  2.83s/it]
#
#
# 100%|██████████| 714/714 [00:36<00:00, 19.68it/s]
#  55%|█████▍    | 6/11 [00:16<00:14,  2.85s/it]
